# %%
import opendataloader_pdf

# %%
opendataloader_pdf.convert(
    input_path=["D:/ETL/District Court/Maharashtra/Ahmednagar/Ahmednagar Civil Court/01-01-2024_31-12-2024/01-01-2024_31-12-2024_1.pdf"],
    output_dir= "D:/ETL/opendataloader output",
    format = "markdown, json",
    hybrid = "hancom-ai",
    hybrid_hancom_ai_ocr_strategy="force"
 )
# Out:
# Error: 'java' command not found. Please ensure Java is installed and in your system's PATH.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 opendataloader_pdf.convert(
#       2     input_path=["D:/ETL/District Court/Maharashtra/Ahmednagar/Ahmednagar Civil Court/01-01-2024_31-12-2024/01-01-2024_31-12-2024_1.pdf"],
#       3     output_dir= "D:/ETL/opendataloader output",
#       4     format = "markdown, json",
#
# ...
